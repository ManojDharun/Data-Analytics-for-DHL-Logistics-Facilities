# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('DHL_Facilities.csv')
df.head(20)
# Out:
#                X             Y  OBJECTID  FEATURE_ID  \
# 0  -1.120834e+07  5.030051e+06         1        2093
# 1  -8.043436e+06  5.299085e+06         2        2293
# 2  -8.045972e+06  5.301971e+06         3        2294
# 3  -8.046142e+06  5.301455e+06         4        2299
# 4  -8.053022e+06  5.367961e+06         5        2597
# 5  -7.992278e+06  5.623122e+06         6        2853
# 6  -9.407483e+06  4.583990e+06         7        4305
# 7  -8.071232e+06  5.217006e+06         8        6771
# 8  -8.072775e+06  5.218061e+06         9        6772
# 9  -8.081281e+06  5.212345e+06        10        6774
# 10 -8.153608e+06  5.211299e+06        11        6802
# 11 -8.157179e+06  5.217533e+06        12        6804
# 12 -8.147414e+06  5.230091e+06        13        6807
# 13 -8.154614e+06  5.228377e+06        14        6808
# 14 -8.204565e+06  5.253491e+06        15        7126
# 15 -8.148776e+06  5.293789e+06        16        7135
# 16 -8.218525e+06  5.220750e+06        17        7160
# ...

# %%
df[df['CITY']=='AUSTIN']
# Out:
#                   X             Y  OBJECTID  FEATURE_ID              NAME  \
# 10846 -1.088857e+07  3.567713e+06     10847       20134        CEDAR PARK
# 10847 -1.088452e+07  3.567673e+06     10848       20135   PAK & SHIP PLUS
# 10853 -1.088358e+07  3.528207e+06     10854       20141           POSTNET
# 10856 -1.087403e+07  3.560402e+06     10857       20144     APL LOGISTICS
# 10861 -1.087188e+07  3.557774e+06     10862       20152     APL LOGISTICS
# ...             ...           ...       ...         ...               ...
# 11258 -1.087881e+07  3.551751e+06     11259       21559  CONTINENTAL BLDG
# 11259 -1.088074e+07  3.553135e+06     11260       21560         ECHELON I
# 11260 -1.088101e+07  3.554080e+06     11261       21561         OFFICEMAX
# 11261 -1.088101e+07  3.554080e+06     11262       21562         OFFICEMAX
# 11262 -1.088154e+07  3.555880e+06     11263       21563  ARBORTUM PLAZA 1
#
#                       ADDRESS       ADDRESS2    CITY STATE    ZIP   LATITUDE  \
# ...

# %%
a = df.groupby(by = 'CITY')['LAST_PICKUP'].count().sort_values(ascending = False).head(15).plot(figsize=(10,7.1),kind = "area",legend = True,color = 'green')
a.set(xlabel = "CITY",ylabel = "NUMBER OF PICKUPS (EACH CITY)")
# Out:
# [Text(0.5, 0, 'CITY'), Text(0, 0.5, 'NUMBER OF PICKUPS (EACH CITY)')]

# %%
s = df.groupby(by = 'ZIP')['OBJECTID'].count().sort_values(ascending = False).head(20).plot(figsize=(15,7.1),kind = "bar",legend = True,color = 'blue')
s.set(xlabel='ZIPCODE',ylabel = 'OBJECTID(COUNT)')
# Out:
# [Text(0.5, 0, 'ZIPCODE'), Text(0, 0.5, 'OBJECTID(COUNT)')]

# %%
df.groupby(by = 'CITY')['OBJECTID'].count().sort_values(ascending = False).head(20).plot(figsize=(20,9),kind = "pie",autopct='%.2f',legend = True)
plt.legend(bbox_to_anchor=(1.0, 1.0))

# %%
import seaborn as sns

# %%
d = df.groupby(by = 'CITY')['OBJECTID'].count()
d.sort_values(ascending=False).plot()
# Out:
# <AxesSubplot:xlabel='CITY'>

# %%
d[d.index == 'HOUSTON']
# Out:
# CITY
# HOUSTON    453
# Name: OBJECTID, dtype: int64

# %%
sns.relplot(data = df['CITY'].head(50))

# %%
import seaborn as sns
import matplotlib.pyplot as plt
val = df.groupby(by = 'STATE')['CITY'].nunique()
ind = val.index
data = pd.DataFrame({'x':ind,
                    'y':val})

# %%
data.sort_values(by='y',ascending=False)
# Out:
#         x    y
# STATE
# CA     CA  382
# NJ     NJ  323
# NY     NY  297
# PA     PA  264
# FL     FL  246
# IL     IL  239
# TX     TX  232
# OH     OH  214
# MI     MI  167
# MA     MA  162
# NC     NC  120
# GA     GA  116
# MO     MO  104
# VA     VA   97
# WI     WI   90
# WA     WA   90
# MD     MD   88
# CT     CT   87
# IN     IN   86
# TN     TN   85
# MN     MN   76
# AL     AL   70
# CO     CO   66
# SC     SC   59
# IA     IA   53
# KY     KY   50
# LA     LA   48
# MS     MS   47
# OR     OR   47
# AR     AR   45
# AZ     AZ   44
# KS     KS   42
# OK     OK   42
# UT     UT   31
# NH     NH   30
# WV     WV   29
# ID     ID   25
# ME     ME   24
# NE     NE   20
# NM     NM   18
# RI     RI   15
# MT     MT   15
# VT     VT   15
# DE     DE   14
# HI     HI   12
# NV     NV   12
# WY     WY   11
# SD     SD    6
# ND     ND    5
# DC     DC    5
# AK     AK    4

# %%
fig,ax = plt.subplots(figsize = (20,8))
s = sns.barplot(x=data['x'],y = data['y'])
s.set(xlabel="STATES",ylabel = "City(COUNT)")
# Out:
# [Text(0.5, 0, 'STATES'), Text(0, 0.5, 'City(COUNT)')]

# %%
#TOP N DELIVERIES BY STATE 
s = df.groupby(by = 'STATE')['OBJECTID'].nunique()
s = s.sort_values(ascending = False)
s = pd.DataFrame(s)
s.head(3)
# Out:
#        OBJECTID
# STATE
# TX         2223
# FL         2101
# CA         2004

# %%
fig,ax = plt.subplots(figsize = (15,8))
d = df.groupby(by = 'STATE')['OBJECTID'].count().head(20)
d.plot.barh()
plt.ylabel('STATES')
plt.xlabel('COUNT(OBJECTID)')
# Out:
# Text(0.5, 0, 'COUNT(OBJECTID)')

# %%
d = df.groupby(by = 'ZIP')['OBJECTID'].count().head(20)
d.plot()
# Out:
# <AxesSubplot:xlabel='ZIP'>

# %%
d = pd.DataFrame(d)
d
# Out:
#       OBJECTID
# ZIP
# 1001         2
# 1002         2
# 1007         1
# 1013         1
# 1027         1
# 1028         1
# 1035         1
# 1040         1
# 1060         1
# 1075         2
# 1085         1
# 1089         5
# 1103         4
# 1104         2
# 1106         1
# 1107         1
# 1109         1
# 1119         1
# 1129         1
# 1201         2

# %%
d = df.groupby(by = 'MATCH_STATUS')['OBJECTID'].count()
colors = ['#FF0000', '#0000FF', '#FFFF00', '#ADFF2F']
d = d.sort_values(ascending = False)
fig,ax = plt.subplots(figsize=(10,10))
plt.pie(d,labels = d.index,colors = colors)
plt.legend()
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title("MATCH STATUS")
# Out:
# Text(0.5, 1.0, 'MATCH STATUS')

# %%
d = df.groupby(by = 'PLACEMENT')['OBJECTID'].count()
d = d.iloc[1:]
d = d.sort_values(ascending = False)
fig,ax = plt.subplots(figsize=(10,10))
plt.pie(d,labels = d.index)
plt.legend()
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title("PLACEMENT STATUS")
# Out:
# Text(0.5, 1.0, 'PLACEMENT STATUS')

# %%
d = df.groupby(by = 'LOCATION_TY')['OBJECTID'].count()
colors = ['#FF0000', '#0000FF', '#FFFF00', '#ADFF2F']
d = d.sort_values(ascending = False)
fig,ax = plt.subplots(figsize=(9.5,9.5))
plt.pie(d,labels = d.index,colors = colors)
plt.legend()
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title("SOURCE LOCATION STATUS")
# Out:
# Text(0.5, 1.0, 'SOURCE LOCATION STATUS')

# %%
d = pd.DataFrame(d)
d
# Out:
#                                 OBJECTID
# LOCATION_TY
# Drop Box                           19776
# DHL Authorized Shipping Center      3885
# DHL Staffed Facility                 326
# Drop Off Facility                     85

# %%
d = df.groupby(by = 'LOCATION_TH')['OBJECTID'].count()
colors = ['Orange', '#0000FF', '#FFFF00', '#ADFF2F']
d = d.sort_values(ascending = False)
fig,ax = plt.subplots(figsize=(9.5,9.5))
plt.pie(d,labels = d.index,colors = colors)
plt.legend()
centre_circle = plt.Circle((0, 0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title("DESTINATION LOCATION STATUS")
# Out:
# Text(0.5, 1.0, 'DESTINATION LOCATION STATUS')

# %%
d = df['CITY'].groupby(df['FEATURE_ID']).count()
d[0:10].plot(figsize=(10,6.1),kind = "area",legend = True,color = 'green')
# Out:
# <AxesSubplot:xlabel='FEATURE_ID'>

# %%
import folium
from folium import plugins

# %%
import folium
from folium import plugins
CU_Boulder_coords = [42.91528, -72.255417]
m = folium.Map(location=[42.91528,-72.255417])
folium.Marker(CU_Boulder_coords, popup = 'CU Boulder').add_to(m)
markerCluster = folium.plugins.MarkerCluster().add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split
reg = linear_model.LinearRegression()
x = df.iloc[:,0:-3]
y = df.iloc[:,-3]
x_train,y_train,x_test,y_test = train_test_split(x,y,test_size=0.3)
#reg.fit(x_train,y_train)

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")

# %%
Latitude = "45.010168"
Longitude = "-71.795856"
location = geolocator.reverse(Latitude+","+Longitude)

# %%
from geopy.geocoders import Nominatim
geolocator = Nominatim(user_agent="geoapiExercises")
Latitude = "42.91528"
Longitude = "-72.255417"
location = geolocator.reverse(Latitude+","+Longitude)
address = location.raw['address']
city = address.get('city','')
state = address.get('state', '')
country = address.get('country', '')
code = address.get('country_code')
zipcode = address.get('postcode')
print('City : ',city)
print('State : ',state)
print('Country : ',country)
print('Zip Code : ', zipcode)

# %%
from scipy.stats import pearsonr
corr, _ = pearsonr(df['LATITUDE'], df['LONGITUDE'])
corr

# %%
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity
from numpy.linalg import norm
s1 = df.iloc[:,0:2]
s2 = df.iloc[:,10:12]
arr = cosine_similarity([s1,s2])
#arr

# %%
#Corrleation relation between the Attributes

X = df.iloc[:,0:4] #Geo-Codes, ObjectID, FeatureID
Y = df.iloc[:,9:12] #Latitude, Longitude
Z = df.iloc[:,14] #ZipCode
X = pd.concat([X,Y,Z],axis = 1)
Y = df.iloc[:,7]
X = X.replace('Not Available',0)
X = pd.DataFrame(X)
sns.heatmap(X.corr(method='pearson'), cmap="YlGnBu", annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.ensemble import RandomForestClassifier,BaggingClassifier
from sklearn.metrics import precision_score,recall_score,f1_score
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
classifier=RandomForestClassifier(n_estimators=50, random_state=0)  
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state = 0)
x_train
# Out:
#                   X             Y  OBJECTID  FEATURE_ID    ZIP   LATITUDE  \
# 5291  -8.911089e+06  4.943855e+06      5292        3043  15229  40.534046
# 7543  -1.315041e+07  4.048405e+06      7544        2984  91106  34.145863
# 7256  -1.239221e+07  4.061138e+06      7257        2097  85541  34.240478
# 20946 -8.350679e+06  4.888998e+06     20947        6796  19053  40.158471
# 61    -8.217863e+06  5.272305e+06        62       10231  12205  42.738844
# ...             ...           ...       ...         ...    ...        ...
# 13123 -9.661319e+06  3.959103e+06     13124         264  35209  33.479342
# 19648 -8.540768e+06  4.775807e+06     19649        9832  21208  39.376919
# 9845  -1.096385e+07  3.442098e+06      9846       21256  78216  29.520781
# 10799 -1.083948e+07  3.642066e+06     10800       20080  76502  31.071713
# 2732  -1.039278e+07  5.600520e+06      2733       14417  55439  44.866441
#
#         LONGITUDE      CENSUS_CODE
# 5291   -80.049674  420034293003000
# ...

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)

# %%
classifier.fit(x_train,y_train)

# %%
y_pred = classifier.predict(x_test)

# %%
accuracy_score(y_pred,y_test)

# %%
print("precision_score :",precision_score(y_pred,y_test,average='macro'))
print("Recall_score :",recall_score(y_pred,y_test,average = 'macro'))
print("F1_Score :",f1_score(y_pred,y_test,average='macro'))

# %%
len(df['CITY'].unique())

# %%
from sklearn import svm
poly = svm.SVC(kernel='poly')

# %%
poly.fit(x_train,y_train)
# Out:
# SVC(C=1, kernel='poly')

# %%
pred = poly.predict(x_test)

# %%
pred = poly.predict(x_test)
print("Accuracy Score :",accuracy_score(y_test,pred))
print("Precision Score :",precision_score(y_test,pred,average = 'macro'))
print("Recall Score :",Recall_score(y_test,pred,average = 'macro'))
print("F1-Score :",f1_score(y_test,pred,average = 'macro'))

# %%
from sklearn.naive_bayes import GaussianNB  
from sklearn.model_selection import cross_val_score

# %%
classifier = GaussianNB()  
classifier.fit(x_train, y_train) 
pred = classifier.predict(x_test)
scores = cross_val_score(classifier, x_train,y_train, cv=10)
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:676: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=10.
#   warnings.warn(

# %%
np.mean(scores)
# Out:
# 0.378875241062157

# %%
print("precision_score :",precision_score(pred,y_test,average='macro'))
print("Recall_score :",recall_score(pred,y_test,average = 'macro'))
print("F1_Score :",f1_score(pred,y_test,average='macro'))
# Out:
# precision_score : 0.2269817419555284
# Recall_score : 0.15457986404322877
# F1_Score : 0.1699799020683929
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\admin\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
def result():
    temp=[]
    columns=['City_Code_Hospital','Available Extra Rooms in Hospital','Hospital_type_code','Department','Ward_Type','Ward_Facility_Code','Type of Admission','Severity of Illness','Age']
    hospitaltypecode_dict={'a':0,'b':1,'c':2,'d':3,'e':4,'f':5,'g':6}
    department_dict={"TB & Chest disease":0,"anesthesia":1,"gynecology":2,"radiotherapy":3,"surgery":4}
    wardtype_dict={'p':0,'q':1,'r':2,'s':3,'t':4,'u':5}
    wardfacilitycode_dict={'a':0,'b':1,'c':2,'d':3,'e':4,'f':5}
    admissiontype_dict={"emergency":0,"trauma":1,"urgent":2}
    severityofillness_dict={"extreme":0,"minor":1,"moderate":2}
    age_dict={"0-10":0,"11-20":9,"21-30":1,"31-40":2,"41-50":3,"51-60":4,"61-70":5,"71-80":6,"81-90":7,"91-100":8}
    temp.append(int(request.form['hospitalcode']))
    temp.append(int(request.form['citycodehospital']))
    temp.append(int(request.form['extrarooms']))
    temp.append(hospitaltypecode_dict[request.form['hospitaltypecode']])
    temp.append(department_dict[request.form['department']])
    temp.append(wardtype_dict[request.form['wardtype']])
    temp.append(wardfacilitycode_dict[request.form['wardfacilitycode']])
    temp.append(admissiontype_dict[request.form['admissiontype']])
    temp.append(severityofillness_dict[request.form['severityofillness']])
    temp.append(age_dict[request.form['age']])
    print(temp)
    df=pd.DataFrame(columns=columns)
    df=pd.concat((df,pd.DataFrame(data=[temp],columns=columns)))
    data=pd.read_csv("D:/LANAARD 7/ACADEMICS/SEM 7/NAALAYA THIRAN/Dataset/train/train.csv")
    


    arr=['Hospital_type_code','Hospital_region_code','Department','Ward_Type','Ward_Facility_Code','Type of Admission','Severity of Illness','Age','Stay']
    le = LabelEncoder()
    for ele in arr:
        label = le.fit_transform(data[ele])
        data.drop(ele, axis=1, inplace=True)
        data[ele]=label
    data.drop('Bed Grade',axis=1,inplace=True)
    data.drop('City_Code_Patient',axis=1,inplace=True)
    features=['Hospital_code','City_Code_Hospital','Available Extra Rooms in Hospital','Hospital_type_code','Department','Ward_Type','Ward_Facility_Code','Type of Admission','Severity of Illness','Age','Stay']
    X_train, X_test, y_train, y_test = train_test_split(data[features[:-1]], data['Stay'], test_size=0.1, random_state=42)
    dtree = DecisionTreeClassifier()
    dtree = dtree.fit(X_train, y_train)
    result=dtree.predict(df)
    print("result : ",result)
    result_dict={0:"0-10 days",1:"10-20 days",2:"20-30 days",3:"30-40 days",4:"40-50 days",5:"50-60 days",6:"60-70 days",7:"70-80 days",8:"80-90 days",9:"90-100 days",10:"more than 100 days"}
    result=result_dict[result[0]]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('DHL_Facilities.csv')
df.head(20)
# Out:
#                X             Y  OBJECTID  FEATURE_ID  \
# 0  -1.120834e+07  5.030051e+06         1        2093
# 1  -8.043436e+06  5.299085e+06         2        2293
# 2  -8.045972e+06  5.301971e+06         3        2294
# 3  -8.046142e+06  5.301455e+06         4        2299
# 4  -8.053022e+06  5.367961e+06         5        2597
# 5  -7.992278e+06  5.623122e+06         6        2853
# 6  -9.407483e+06  4.583990e+06         7        4305
# 7  -8.071232e+06  5.217006e+06         8        6771
# 8  -8.072775e+06  5.218061e+06         9        6772
# 9  -8.081281e+06  5.212345e+06        10        6774
# 10 -8.153608e+06  5.211299e+06        11        6802
# 11 -8.157179e+06  5.217533e+06        12        6804
# 12 -8.147414e+06  5.230091e+06        13        6807
# 13 -8.154614e+06  5.228377e+06        14        6808
# 14 -8.204565e+06  5.253491e+06        15        7126
# 15 -8.148776e+06  5.293789e+06        16        7135
# 16 -8.218525e+06  5.220750e+06        17        7160
# ...

# %%
import numpy as np
import pickle
from flask import Flask, request, render_template
import numpy as np
import pickle
from flask import Flask, request, render_template

# %%
@app.route("/")
def home():
    return render_template("Login.html")

@app.route("/template",methods=["POST","GET"])
def index():
    return render_template("index.html")


@app.route("/template",methods=["POST","GET"])
def result():
    temp=[]
    columns=['X','Y','OBJECTID','FEATURE_ID','ZIP','LATITUDE','LONGITUDE','CENSUS_CODE']
    temp.append(int(request.form['X']))
    temp.append(int(request.form['Y']))
    temp.append(int(request.form['objectid']))
    temp.append(int(request.form['featureid']))
    temp.append(int(request.form['zipcode']))
    temp.append(int(request.form['latitude']))
    temp.append(int(request.form['longitude']))
    temp.append(int(request.form['censuscode']))
    df = pd.read_csv('DHL_Facilities.csv')
    X = df.iloc[:,0:4] #Geo-Codes, ObjectID, FeatureID
    Y = df.iloc[:,9:12] #Latitude, Longitude
    Z = df.iloc[:,14] #ZipCode
    X = pd.concat([X,Y,Z],axis = 1)
    Y = df.iloc[:,7]
    X = X.replace('Not Available',0)
    X = pd.DataFrame(X)
    df1=pd.DataFrame(columns=columns)
    df2=pd.concat((df1,pd.DataFrame(data=[temp],columns=columns)))
    classifier=RandomForestClassifier(n_estimators=50, random_state=0)  
    x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state = 0)
    classifier.fit(x_train,y_train)
    res = classifier.predict(df2)
    return render_template("data.html",result = res)


#@app.route("/login",methods=["POST","GET"])
#def login():
#    return render_template("login.html")

# %%
if __name__=='__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [19/Nov/2022 18:35:48] "GET / HTTP/1.1" 404 -
# 127.0.0.1 - - [19/Nov/2022 18:35:48] "GET /favicon.ico HTTP/1.1" 404 -

# %%
from flask import Flask
app = Flask(__name__)

@app.route("/")
def home():
    return render_template("Login.html")

@app.route("/index",methods=["POST","GET"])
def index():
    return render_template("index.html")

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [21/Nov/2022 18:08:59] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Nov/2022 18:09:00] "GET /vendor/jquery/jquery.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [21/Nov/2022 18:09:00] "GET /avathar.jpg HTTP/1.1" 404 -
# 127.0.0.1 - - [21/Nov/2022 18:09:00] "GET /vendor/bootstrap/js/bootstrap.bundle.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [21/Nov/2022 18:09:00] "GET /vendor/jquery-easing/jquery.easing.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [21/Nov/2022 18:09:00] "GET /js/sb-admin-2.min.js HTTP/1.1" 404 -
# 127.0.0.1 - - [21/Nov/2022 18:09:08] "POST /index.html HTTP/1.1" 404 -

# %%
temp=[]
columns=['X','Y','OBJECTID','FEATURE_ID','ZIP','LATITUDE','LONGITUDE','CENSUS_CODE']
df = pd.read_csv('DHL_Facilities.csv')
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
X = df.iloc[:,0:4] #Geo-Codes, ObjectID, FeatureID
Y = df.iloc[:,9:12] #Latitude, Longitude
Z = df.iloc[:,14] #ZipCode
X = pd.concat([X,Y,Z],axis = 1)
Y = df.iloc[:,7]
X = X.replace('Not Available',0)
X = pd.DataFrame(X)
df1=pd.DataFrame(columns=columns)
df2=pd.concat((df1,pd.DataFrame(data=[temp],columns=columns)))
classifier=RandomForestClassifier(n_estimators=50, random_state=0)  
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state = 0)
classifier.fit(x_train,y_train)
res = classifier.predict(df2)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12852/1021653309.py in <module>
#       1 temp=[]
#       2 columns=['X','Y','OBJECTID','FEATURE_ID','ZIP','LATITUDE','LONGITUDE','CENSUS_CODE']
# ----> 3 temp.append(int(request.form['X']))
#       4 temp.append(int(request.form['Y']))
#       5 temp.append(int(request.form['objectid']))
#
# ~\anaconda3\lib\site-packages\werkzeug\local.py in __get__(self, instance, owner)
#     430
#     431         try:
# --> 432             obj = instance._get_current_object()
#     433         except RuntimeError:
#     434             if self.fallback is None:
#
# ~\anaconda3\lib\site-packages\werkzeug\local.py in _get_current_object(self)
#     552         """
#     553         if not hasattr(self.__local, "__release_local__"):  # type: ignore
# --> 554             return self.__local()  # type: ignore
# ...

# %%
from sklearn.ensemble import RandomForestClassifier,BaggingClassifier
from sklearn.metrics import precision_score,recall_score,f1_score
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
X = df.iloc[:,0:4] #Geo-Codes, ObjectID, FeatureID
Y = df.iloc[:,9:12] #Latitude, Longitude
Z = df.iloc[:,14] #ZipCode
X = pd.concat([X,Y,Z],axis = 1)
Y = df.iloc[:,7]
X = X.replace('Not Available',0)
X = pd.DataFrame(X)

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state = 0)

# %%
x_train
# Out:
#                   X             Y  OBJECTID  FEATURE_ID    ZIP   LATITUDE  \
# 5291  -8.911089e+06  4.943855e+06      5292        3043  15229  40.534046
# 7543  -1.315041e+07  4.048405e+06      7544        2984  91106  34.145863
# 7256  -1.239221e+07  4.061138e+06      7257        2097  85541  34.240478
# 20946 -8.350679e+06  4.888998e+06     20947        6796  19053  40.158471
# 61    -8.217863e+06  5.272305e+06        62       10231  12205  42.738844
# ...             ...           ...       ...         ...    ...        ...
# 13123 -9.661319e+06  3.959103e+06     13124         264  35209  33.479342
# 19648 -8.540768e+06  4.775807e+06     19649        9832  21208  39.376919
# 9845  -1.096385e+07  3.442098e+06      9846       21256  78216  29.520781
# 10799 -1.083948e+07  3.642066e+06     10800       20080  76502  31.071713
# 2732  -1.039278e+07  5.600520e+06      2733       14417  55439  44.866441
#
#         LONGITUDE      CENSUS_CODE
# 5291   -80.049674  420034293003000
# ...

# %%
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
columns=['X','Y','OBJECTID','FEATURE_ID','ZIP','LATITUDE','LONGITUDE','CENSUS_CODE']
df1=pd.DataFrame(columns=columns)
df2=pd.concat((df1,pd.DataFrame(data=[temp],columns=columns)))
classifier=RandomForestClassifier(n_estimators=50, random_state=0)  
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state = 0)
classifier.fit(x_train,y_train)
res = classifier.predict(df2)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_12852/3393851538.py in <module>
#      11 classifier=RandomForestClassifier(n_estimators=50, random_state=0)
#      12 x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state = 0)
# ---> 13 classifier.fit(x_train,y_train)
#      14 res = classifier.predict(df2)
#
# ~\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py in fit(self, X, y, sample_weight)
#     448             # parallel_backend contexts set at a higher level,
#     449             # since correctness does not rely on using threads.
# --> 450             trees = Parallel(
#     451                 n_jobs=self.n_jobs,
#     452                 verbose=self.verbose,
#
# ~\anaconda3\lib\site-packages\joblib\parallel.py in __call__(self, iterable)
# ...

# %%
from sklearn.ensemble import RandomForestClassifier,BaggingClassifier
from sklearn.metrics import precision_score,recall_score,f1_score
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv('DHL_Facilities.csv')
X = df.iloc[:,0:4] #Geo-Codes, ObjectID, FeatureID
Y = df.iloc[:,9:12] #Latitude, Longitude
Z = df.iloc[:,14] #ZipCode
X = pd.concat([X,Y,Z],axis = 1)
Y = df.iloc[:,7]
X = X.replace('Not Available',0)
X = pd.DataFrame(X)
# Out:
# 0          NORTH PLATTE
# 1                 KEENE
# 2                 KEENE
# 3                 KEENE
# 4             CLAREMONT
#               ...
# 24067           WARWICK
# 24068    EAST GREENWICH
# 24069         WAKEFIELD
# 24070         WAKEFIELD
# 24071         WAKEFIELD
# Name: CITY, Length: 24072, dtype: object

# %%
classifier=RandomForestClassifier(n_estimators=50, random_state=0)  
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state = 0)

# %%
classifier.fit(x_train,y_train)
# Out:
# RandomForestClassifier(n_estimators=50, random_state=0)

# %%
temp = []
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
temp.append(0)
columns=['X','Y','OBJECTID','FEATURE_ID','ZIP','LATITUDE','LONGITUDE','CENSUS_CODE']
df1=pd.DataFrame(columns=columns)
df2=pd.concat((df1,pd.DataFrame(data=[temp],columns=columns)))
res = classifier.predict(df2)
df = pd.read_csv('DHL_Facilities.csv')

# %%
import numpy as np
import pickle
from flask import Flask, request, render_template,url_for
import numpy as np
import pickle
from flask import Flask
app = Flask(__name__)

@app.route("/",methods=["GET","POST"])
def result():
        temp=[]
        result = 0
        columns=['X','Y','OBJECTID','FEATURE_ID','ZIP','LATITUDE','LONGITUDE','CENSUS_CODE']
        if(request.form.get('X') != None):
            temp.append(int(request.form.get('Y')))
            temp.append(int(request.form.get('Y')))
            temp.append(int(request.form.get('objectid')))
            temp.append(int(request.form.get('featureid')))
            temp.append(int(request.form.get('zipcode')))
            temp.append(int(request.form.get('latitude')))
            temp.append(int(request.form.get('longitude')))
            temp.append(int(request.form.get('censuscode')))
            X = df.iloc[:,0:4] #Geo-Codes, ObjectID, FeatureID
            Y = df.iloc[:,9:12] #Latitude, Longitude
            Z = df.iloc[:,14] #ZipCode
            X = pd.concat([X,Y,Z],axis = 1)
            Y = df.iloc[:,7]
            X = X.replace('Not Available',0)
            X = pd.DataFrame(X)
            x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size=0.2,random_state = 0)
            df1=pd.DataFrame(columns=columns)
            df2=pd.concat((df1,pd.DataFrame(data=[temp],columns=columns)))
            classifier=RandomForestClassifier(n_estimators=50, random_state=0) 
            classifier.fit(x_train,y_train)
            result = classifier.predict(df2)
            result = result[0]
        return render_template("data.html",result = result)

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [22/Nov/2022 00:24:39] "GET / HTTP/1.1" 200 -

# %%
request.form.get('X')
